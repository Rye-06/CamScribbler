# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read image
img=cv2.imread("pp.png",cv2.IMREAD_GRAYSCALE)
#Show image
cv2.imshow("Iron Golem Retextured",img)

#Write image
cv2.imwrite("pp2.png",img)
#Wait Key to not run program infinitely
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Color spaces: In this case, RGB
img=cv2.imread("pp.png")
B,G,R=cv2.split(img)
#The white areas in the 3 images are the colours
cv2.imshow("Blue",B)
cv2.imshow("Green",G)
cv2.imshow("Red",R)
cv2.imshow("OG",img)
#Wait Key to not run program infinitely
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("pp.png")
cv2.imshow("OG",img)
for i in img:
    i+=128
cv2.imshow("Brighter",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# <h1>Interpolation for Image Resizing</h1>

# %%
image = cv2.imread("pp.png", 0)
 
half = cv2.resize(image, (0, 0), fx = 0.1,fy=0.1)
bigger = cv2.resize(image, (1050, 1610))
 
stretch_near = cv2.resize(image, (780, 540),
               interpolation = cv2.INTER_CUBIC)
 
 
Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[image, half, bigger, stretch_near]
count = 4
 
for i in range(count):
    plt.subplot(2, 2, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])
 
plt.show()

# %%
#cv.erode(): Makes boundaries at edges in images
kernel=np.ones((5,5))
im2=cv2.erode(image,kernel,cv2.BORDER_REFLECT)
cv2.imshow("Eroded",im2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:301180)
# at w.execute (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:300551)
# at w.start (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:296215)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:310950)
# at async t.CellExecutionQueue.start (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:310490)

# %%
#Blurring(Done for preprocessing image before applying ML)
# Gaussian Blurring- Blurring by Gaussian function
# Median Blur- Blurring but under certain conditions, edges are preserved
# Bilateral Blur- Blurring with all edges preserved

image=cv2.imread('pp3.png')
cv2.imshow("bruhnights",image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:301180)
# at w.execute (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:300551)
# at w.start (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:296215)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:310950)
# at async t.CellExecutionQueue.start (c:\Users\yashm\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:310490)

# %%
# Warp Perspective
img=cv2.imread("Cards.jpg")

width, height= 250,350
# Points of card (found by opening image in paint)
pts1=np.float32([[246,118],[404,213],[102,329],[266,429]])
#Warp to make image of this dimensions-
pts2=np.float32([[0,0],[width,0],[0,height],[width,height]])
#Image transformation matrix
matrix=cv2.getPerspectiveTransform(pts1,pts2)
imgOutput=cv2.warpPerspective(img,matrix,(width,height))
cv2.imshow("Cards",img)
cv2.imshow("Card",imgOutput)
cv2.waitKey(0)
cv2.destroyAllWindows()
